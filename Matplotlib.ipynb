# %%
# Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
x=np.random.rand(50)
x
# Out:
# array([0.18553735, 0.97895773, 0.20522764, 0.77551544, 0.78407211,
#        0.95481047, 0.23499824, 0.49649087, 0.87540348, 0.67437346,
#        0.77566287, 0.26036585, 0.29309949, 0.10033477, 0.20993734,
#        0.95092642, 0.07035942, 0.57139456, 0.54645026, 0.81756361,
#        0.73811296, 0.14832917, 0.7264628 , 0.00617408, 0.86124505,
#        0.676276  , 0.43776474, 0.41191256, 0.84830928, 0.67105285,
#        0.31471037, 0.29400256, 0.48230676, 0.83609313, 0.97269575,
#        0.62261242, 0.77345411, 0.13514345, 0.05445989, 0.52542176,
#        0.07014937, 0.86969422, 0.24279842, 0.76417179, 0.20530523,
#        0.36927583, 0.65188829, 0.80620438, 0.86595775, 0.49138042])

# %%
np.random.randn(50)
# Out:
# array([-1.34901661, -0.86076699,  0.22275442, -1.42841459,  1.5527375 ,
#        -0.86539131, -0.74153742, -1.9303173 ,  0.34942079,  2.53062503,
#        -1.47210544,  3.40700025,  0.0292955 , -0.02721945, -0.33295419,
#         0.32134767,  0.98786991, -1.40612737, -1.59964492,  0.689065  ,
#        -1.95878419,  0.52066704,  1.0326413 ,  0.31654625,  0.02591943,
#         0.44765556,  0.25495719,  2.00867389, -0.25223356, -2.66687385,
#         0.11416913, -0.86553511, -0.88822688, -0.31287996, -1.69642406,
#        -1.04668415,  0.41454674, -0.11898172,  0.01957942, -0.28687327,
#         0.70556024,  0.40071156,  0.66620843, -2.14157882, -0.6638256 ,
#         0.12458678, -1.1121492 ,  1.63819876, -0.05359788,  1.59969117])

# %%
pd.DataFrame(np.random.randn(1000),columns=['Data'],index=pd.date_range('2024-07-11',periods=1000))
# Out:
#                 Data
# 2024-07-11 -0.077160
# 2024-07-12 -0.028978
# 2024-07-13  0.785057
# 2024-07-14  0.559575
# 2024-07-15 -1.242705
# ...              ...
# 2027-04-02 -0.731677
# 2027-04-03  0.830309
# 2027-04-04  0.413483
# 2027-04-05  1.159321
# 2027-04-06  0.631946
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['Data'],index=pd.date_range('2024-07-11',periods=1000))

# %%
df.plot(figsize=[20,8])
# Out:
# <Axes: >

# %%
y=np.random.rand(50)

# %%
x
# Out:
# array([0.30283778, 0.59873878, 0.41530872, 0.59788299, 0.76056738,
#        0.69376117, 0.5420431 , 0.93482336, 0.80202841, 0.48390654,
#        0.27119264, 0.67212627, 0.26930581, 0.87382499, 0.4961913 ,
#        0.84238055, 0.79226559, 0.16345282, 0.36784703, 0.21031712,
#        0.45250205, 0.17760193, 0.93316764, 0.80451108, 0.1931262 ,
#        0.15469849, 0.70410435, 0.14811912, 0.93163547, 0.3922024 ,
#        0.30317407, 0.20802351, 0.85414975, 0.66312792, 0.87033939,
#        0.50826503, 0.43945756, 0.91866332, 0.67442429, 0.91205433,
#        0.39372748, 0.96390713, 0.63511214, 0.08125003, 0.79751211,
#        0.93494165, 0.26416217, 0.2633651 , 0.4188534 , 0.44171909])

# %%
y
# Out:
# array([0.25588212, 0.42442788, 0.21202616, 0.84838519, 0.22216324,
#        0.3564928 , 0.99992748, 0.63809993, 0.14842518, 0.47837469,
#        0.45748939, 0.30973614, 0.65089096, 0.68103032, 0.11802899,
#        0.55055921, 0.02364978, 0.97687186, 0.19718376, 0.94970226,
#        0.19818933, 0.64969251, 0.18476027, 0.84874169, 0.44721863,
#        0.00694561, 0.96839966, 0.7019353 , 0.09350449, 0.25889842,
#        0.44456851, 0.05306132, 0.05305474, 0.29884761, 0.68329161,
#        0.85756672, 0.77703499, 0.20101348, 0.3639695 , 0.54004818,
#        0.57251878, 0.0401484 , 0.53669693, 0.633287  , 0.13101039,
#        0.12339731, 0.33991367, 0.01453223, 0.64674439, 0.32550069])

# %%
# Scatter Plot
plt.scatter(x,y)

# %%
# Line Plot
x=[1,2,3,4,5]
y=[5,2,7,8,1]

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('Line Chart')
plt.xlabel('Days')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(x,y,color='red')
plt.title('Line Chart')
plt.xlabel('Days')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(x,y,color='red',marker='o',linestyle='--',linewidth=4)
plt.title('Line Chart')
plt.xlabel('Days')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(x,y,color='red',marker='o',markersize=15,linestyle='--',linewidth=4)
plt.title('Line Chart')
plt.xlabel('Days')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(x,y,color='red',marker='o',markersize=15,linestyle='--',linewidth=4)
plt.title('Line Chart')
plt.xlabel('Days')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
x1=[1,2,3,4,5]
y1=[5,1,7,8,2]
y2=[7,8,3,5,1]
plt.plot(x1,y1,color='yellow',marker='o',linestyle='--',linewidth=3,markersize=6,label='line y1')
plt.plot(x1,y2,color='red',marker='o',linestyle='--',linewidth=3,markersize=6,label='line y2')
plt.legend()
plt.grid()
plt.show()

# %%
x=np.linspace(1,10,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %%
x=np.linspace(1,10,100)
plt.plot(x,np.sin(x),'--')
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))
plt.subplot(1,2,2)
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))
plt.subplot(2,1,2)
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))
plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
plt.subplot(2,2,3)
plt.plot(x,np.tan(x))
plt.subplot(2,2,4)
plt.plot(x,np.sin(x))
plt.show()

# %%
plt.plot(x,np.cos(x),color='blue')
plt.show()

# %%
plt.plot(x,np.cos(x),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x,np.cos(x),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x,np.cos(x),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.title('basic syntax')
plt.xlabel('x label')
plt.ylabel('y label')
plt.axis('equal')
plt.grid()
plt.show()

# %%
# Histogram
data=np.random.randn(1000)
plt.hist(data,edgecolor='white')
plt.show()

# %%
# Histogram
data=np.random.randn(1000)
plt.hist(data,color='red',bins=20,edgecolor='white')
plt.show()

# %%
# Staged histogram
data1=np.random.normal(0,1,5000)
data2=np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([ 1.15046366,  0.16177637, -0.20574574, ...,  0.73353673,
#        -0.72770491, -0.57778119])

# %%
data2
# Out:
# array([7.59797077, 5.95705745, 0.49405719, ..., 0.19172091, 1.86708103,
#        2.47636771])

# %%
plt.hist([data1,data2],color=['r','b'],label=['dist1','dist2'],edgecolor='w')
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Staged Histogram")
plt.legend()
plt.show()

# %%
# scatter plot
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.58988364, 0.79952087, 0.73583297, 0.99377286, 0.40917603,
#        0.8264802 , 0.22268937, 0.58937639, 0.9022947 , 0.48330277,
#        0.01604222, 0.82254294, 0.03798096, 0.351134  , 0.13406178,
#        0.55859453, 0.36671866, 0.64289426, 0.71256587, 0.02830852,
#        0.02015359, 0.9884567 , 0.45602621, 0.22522321, 0.10300507,
#        0.66743961, 0.80885729, 0.8728368 , 0.65555043, 0.78879449,
#        0.85955242, 0.10871321, 0.76179449, 0.38588617, 0.85034991,
#        0.51213061, 0.05989062, 0.02770299, 0.0764433 , 0.47561867,
#        0.83463839, 0.9965074 , 0.42077009, 0.69537556, 0.70666981,
#        0.08172119, 0.27186348, 0.79879181, 0.35344248, 0.75940938])

# %%
y
# Out:
# array([0.07913679, 0.89977951, 0.46732107, 0.4252079 , 0.1164433 ,
#        0.10167819, 0.95108856, 0.52345929, 0.57793413, 0.14147372,
#        0.77310528, 0.302255  , 0.98440469, 0.94755403, 0.62451005,
#        0.0099636 , 0.25718541, 0.35612771, 0.18409926, 0.72319995,
#        0.79936093, 0.95422794, 0.52132115, 0.0034835 , 0.34660773,
#        0.55898394, 0.7367443 , 0.30088867, 0.34510156, 0.36032912,
#        0.21428211, 0.70279335, 0.99310049, 0.1459563 , 0.72439703,
#        0.80834694, 0.15741837, 0.02449092, 0.06931392, 0.84629875,
#        0.62357788, 0.11941406, 0.9665827 , 0.11791297, 0.8417327 ,
#        0.07966714, 0.21437469, 0.41948742, 0.04204351, 0.78346593])

# %%
plt.scatter(x,y,color ='red',marker='o')
plt.show()

# %%
# bar plot
# To see distribution of categorical data
x=['a','b','c','d']
y=[4,6,1,10]
plt.bar(x,y,color='red')
# Out:
# <BarContainer object of 4 artists>

# %%
x=['a','b','c','d']
y=[4,6,1,10]
plt.barh(x,y,color='red')
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart
langs=['C','Python','Java']
students=[20,100,40]
plt.pie(students,labels=langs,autopct="%1.1f%%")
plt.title("Pie Chart")
plt.show()

# %%
# focus on one segment
langs=['C','Python','Java']
students=[20,100,40]
plt.pie(students,labels=langs,autopct="%1.1f%%",explode=(0.0,0.1,0.1),shadow="True")
plt.title("Pie Chart")
plt.show()

# %%
# 3D plots
x=np.random.rand(20)
y=np.random.rand(20)
z=np.random.rand(20)
fig=plt.figure()
ax=fig.add_subplot(projection="3d")
plt.scatter(x,y,z,c='r',marker='o')
